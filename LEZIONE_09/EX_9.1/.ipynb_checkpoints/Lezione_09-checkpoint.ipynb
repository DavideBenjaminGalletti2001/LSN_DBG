# %% [markdown]
# # <span style="color:red"> Numerical Simulation Laboratory (NSL) </span>

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h1><font color='ForestGreen'>ESERCITAZIONE 9: Ottimizzazione e Algoritmi Genetici </font> </h1>

# %% [markdown]
# <h3><font color = 'LightGreen'>Algoritmi Genetici</font></h3>

# %% [markdown]
# In questa esercitazione l'obiettivo e' risolvere il problema del commesso viaggiatore servendosi dei cosiddetti algoritimi genetici, una tecnica di
# ottimizzazione che prende ispirazione dai processi biologici delle specie animali e dai fenomeni di mutazione genetica. In sistesi, tale tecnica si puo' definire:
# <lo>
#     <li>Gradient-Free </li>
#     <li>Stochastic </li>
#     <li>Population Based</li>
#     <li>Global Saerching</li>
# </lo>
# Per essere piu' chiari, i GAs per lavorare soddisfano alcune caratteristiche: generalmente ricorrono ad una codifica dei parametri, piuttusto che usare i parametri effettivi; sfruttano una modalita' di ricerca in cui viene manipolata ed elaborata una popolazione di soluzioni candidate; estraggono informazione in modo diretto, cioe' senza far uso di gradiente; contempleano un elemento di stocasticita', per cui hanno proprieta' di transizione
# probabilistiche.Come codifica, vi sono molteplici scelte; per esemplificare e' possibile considerare una stringa binaria, un numero reale, strutture dati oppure pure elementi di programmi.
#
# in termini schematici, il funzionamento di un algoritmo genetico consta dei seguenti punti fondamentali:
#
# 1. Si parte da una popolazione di n-cromosomi, cioe' soluzioni candidate codificate: la scelta piu' semplice e conveniente spesso e' quella di stringhe di bit.
# 2. Si calcola il fitness per ogni cromosoma della popolazione: tale quantita' e' una misura della capacita' di ottimizzazione ed e' tanto piu' basso
#    quanto maggiore e' il fitness.
# 3. Si ripetono i seguenti step finche' non si decide di stoppare l'evoluzione
#    <p style = "text-align:left">
#        - Si seleziona una coppia di cromosomi genitori con probabilita' proporzionale al fitness, cioe' si implementa un metodo
#            per simulare i processi di selezione naturale:  una sorta di rulette truccata. L'estrazione dell'indice segue in particolare la legge:
#                  $j= int(M \times r^p)+1$<br>
#       - Con probabilita' $p_c$ si prendera' questa coppia e si produrra incrocio a punto fisso, tipicamente a punto singolo.
#            tale procedura va a rapprasentare il fenomeno di Crossover.<br>
#     - Si effettua mutazione di queste nuovi o vecchi inidividui, il che riproduce il concetto di alterazione genetico.<br>
#    </p>
# 5. Si sostitusice la popolazione di partenza cn una nuova, generalmente assunta della medesima dimensione.
# 6. Si ripete il processo generando via via una generazione dopo l'altra, cioe' una popolazione di cromosomi-individui-da cui selezionare l'ottimo valutandoli sulla funzione costo.
#
# Un GAs, in breve, quindi prende una popolazione-insieme- di soluzioni candidate -cromosomi- del problema, quali possono essere per il problema del commesso viaggiatore nient'altro che i possibili percorsi, per ogni elemento di tale popolazione di va a valutare la funzione perdita per imporre la selezine naturale e generare cosi' una generazione di figli, cioe' una nuova popolazione cui si ripete la selezione di cui sopra in funzione dell'adattabilita'. Insieme poi alla selezione naturale, i cromosomi che vanno a costituire la popolazion epossono a loro volta subire alterazioni genetiche: anzitutto crossover, dopodiche' mutazioni genetiche di varia natura.

# %% [markdown]
# <h3><font color = 'LightGreen'>Intro: Problema del Commesso Viaggiatore TSP</font></h3>

# %% [markdown]
# Come osservato, quanto ci si propone e' utilizzare gli algoritmi genetici per ottimizzare il problema del commesso viaggiatore:
# <br>
# <span style = "color:blue"> il commesso deve visitare una e una sola volta città in posizioni partendo da una e tornandoci, minimizzando il percorso totale </span>
# <br>
# Tale percorso, sara' della forma:
# <p style = "text-align:center">
# $L^{(2)}(\vec{x}_1, \vec{x}_2, \dots, \vec{x}_N) = \sum_{i=1}^{N} |\vec{x}_i-\vec{x}_{i+1}|^2
# \qquad \text{oppure} \qquad
# L^{(1)}(\vec{x}_1, \vec{x}_2, \dots, \vec{x}_N) = \sum_{i=1}^{N} |\vec{x}_i-\vec{x}_{i+1}|$
# </p>
#
# In maniera arbitraria, si e' optato per la prima opzione.
#
# Forse non seguendo il principio della strada piu' semplice e sicura, in questo elaborato si e' codificato il singolo cromosoma-rappresentante il percorso
# fatto dal commesso viaggiatore-come un vector-sfruttando la potenza e versatilita' della classe STL in c++ di iteratori ad un opportuno vector di citta', ove queste sono rappresentate a loro volta da una ulteriore classe per distinguere le varie casisitiche: city; city_circ; city_quad...; cioe' citta' distribuite casualmente su un piano; citta' distribuite su circonferenza; citta' distribuite dentro un quadrato...
# Ragion per cui, va da se' che la classe TSP andra' ad essere templetizzata.
# Un'alternativa, altrettanto valida e forse concettualmente e nella pratica piu' semplice da implementare, sarebbe stata scegliere una codifica a vector di interi: etichettando ogni citta' con un numero, si sarebbe perfettamente potuto ottenere ogni percorso tramite semplice permutazione: procedura che, tramite  semplici modifiche del codice, e' stata implementata nell'esercitazione 10. Tale necessita' e' derivata dal fatto di dover ricorrere, per parallelizzare il programma, alle librerie MPI: d'altra parte, queste supportano, in linea di principio, solo il formato C, il che rende impossibile specificare vector di classi personalizzati. In questo caso addirittura vector di iteratori ad oggetti non primitivi del linguaggio come la classe rappresentante le citta'. Un alternativa, disponibile sul mercato, e' ricorrere alle librerie Boost MPI: una estensione c++ dell'MPI.

# %% [markdown]
# Aldila' di queste considerazione, che rigurdano specificatamente la esercitazione seguente, opportuno e' descrivere il codice sviluppato.

# %% [markdown]
# <h3><font color = 'LightGreen'>Codice:</font></h3>

# %% [markdown]
# In totale, come gia' preliminarlmente anticipato, per lo sviluppo di questo codice sono stati sviluppate degli oggetti opportuni.
# Una classe astratta GAs, il cui significato e' definire i metodi virtuali potenzialmente comuni a tutti gli algoritmi genetici e specializzantisi
# in base alla situazione: reproduction(), mutations(), crossover(),...tutte le varie mutazioni possibile. una classe figlia TSP, ovvero il cuere della esercitazione e in cui son implementati i metodi-solo virtuali in GAs-per risolvere il problema del commesso viaggiatore. Un Oggetto funtore per definire la relazione d'ordine con cui valutare i diversi percorsi della popolazione e poterli cosi' riordinare col metodo sort(). Una classe city-madre-, da cui distinguo le classi figlie city_quad e city_circ d'interesse per la consegna dell'esercizio e che descrivono rispettivamente una griglia di citta' dentro un quadra o distribuite su una circonferenza.

# %% [markdown]
# <h4><font color = 'Black'>Main:</font></h4>

# %% [markdown]
# E  molto semplice: pesca da file di input, input.dat, i parametri di input-numero citta', numero cromosomi per popolazione, numero generazioni, numero swap citta' input(sebbene non necessario in quanto si e' sostitutito con una operazione shuffle data dalla STL)-numero scambi del crossoover, per definire i vettori su cui si scambia.

# %% [markdown]
# <h4><font color = 'Black'>GAs:</font></h4>

# %% [markdown]
# Come dicevo sopra, e' nient'altro che una classe astratta madre che contempla metodi virtuali: mutations, reproduction, crossover,...

# %% [markdown]
# <h4><font color = 'Black'>TSP:</font></h4>

# %% [markdown]
# Si hanno due tipi di costruttori: uno in cui oltre che alla dimensione del cromosoma, alla dimensione della popolazione e al numero di generazioni, passo pure swap citta' input; l'altra in cui passo solo i primi tre parametri e delego alla funzione random_shuffle l'operazione compiuta da swap.
# Si e' costrutioto un metodo reproduction(dim_scambi) di tipo void nel valore di return: con questo semplicemente genero una nuova popolazione data a partire dalla precedente. Tale riproduzione e' progettatto per riflettere il comportamento della
# Dentro questo, poi, sono utilizzati due ulteriori metodi: il metodo mutations, in cui sono implementati gli arrangiamenti genetici di singolo individuo;
# il metodo crossover, in cui invece e' implementata l'operazione di ricombinazione tra due individui.
# Infine si e' aggiunto un metodo reproductionAll in cui eseguo tutto il processo di ottimizzazione includendo quindi il ciclo per formare tutte le generazione date in input.

# %% [markdown]
# <h4><font color = 'Black'>Funtore</font></h4>

# %% [markdown]
# Una classe per definire la relazione d'ordine tra i vari cromosomi: un cromosoma sara' preferito ad un altro tanto piu' bassa e'
# la funzione costo.

# %% [markdown]
# <h4><font color = 'Black'>City:</font></h4>

# %% [markdown]
# La classe City, strettamente parlando, e' configurata in modo tale da essere una classe madre, da cui discendono le classi figlie
# City_circ e City_quad. Ognuna implementa una vasta maglia di metodi. Il piu' importante, di certo, e' il metodo SetRandom() per costruire una citta' in una posizione casuale in base ai vincoli del problema.

# %% [markdown]
# <h2><font color = 'LimeGreen'>ESERCIZIO 9.1: Algoritmi Genetici, TSP</font></h2>

# %% [markdown]
# <h3><font color = 'LightGreen'>Circonferenza:</font></h3>

# %% [markdown]
# Andiamo, in prima battuta, a plottare la distribuzione delle citta' generate in modo casuale sulla circonferenza.

# %%
plt.figure(figsize = (10,7), facecolor = "ALICEBLUE")
x,y = np.loadtxt("EX_9.1_CIRCONFERENZA/Configurazioni/configurazione0.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x[0],y[0], marker ="*", color = "Magenta", markersize = 16, label = "Start", linestyle = "")
plt.plot(x, y,marker = "o",mec = "Lime" , mfc = "lime", linestyle = "None", c = "INDIGO")
font = {'family':'serif', 'color':'forestgreen','size':'15'}
plt.ylabel('y', fontdict = font)
plt.xlabel('x', fontdict = font)
plt.grid(True)
plt.title('città', fontsize = 20, fontweight = "bold", color = "ForestGreen", family = "Serif")
plt.legend()

x = np.linspace(-1.0, 1.0, 100)
y = np.linspace(-1.0, 1.0, 100)
X, Y = np.meshgrid(x,y)
F = X**2 + Y**2 - 1
plt.contour(X,Y,F,[0], colors = "r", alpha = 0.4)

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# Puo' essere utile andare a visualizzare un esempio di percorso casuale; prendendo quello di input:

# %%
plt.figure(figsize = (10,7), facecolor = "ALICEBLUE")
x,y = np.loadtxt("EX_9.1_CIRCONFERENZA/Configurazioni/configurazione0.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x[0],y[0], marker ="*", color = "Magenta", markersize = 16, label = "Start", linestyle = "")
plt.plot(x, y, marker = "o",mec = "Lime" , mfc = "lime", linestyle = "-", c = "INDIGO")
font = {'family':'serif', 'color':'forestgreen','size':'15'}
plt.ylabel('y', fontdict = font)
plt.xlabel('x', fontdict = font)
plt.grid(True)
plt.title('città', fontsize = 20, fontweight = "bold", color = "ForestGreen", family = "Serif")
plt.legend()

x = np.linspace(-1.0, 1.0, 100)
y = np.linspace(-1.0, 1.0, 100)
X, Y = np.meshgrid(x,y)
F = X**2 + Y**2 - 1
plt.contour(X,Y,F,[0], colors = "r", alpha = 0.4)

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# L'obiettivo e' andare ad ottimizzare il percorso migliore: naturalmente ci aspettiamo che questo coincidera' col vincolo del sistema e che al commesso viaggiatore converra' muoversi lungo la circonferenza.
# Andando a plottare in funzione della generazione l'andamento della funzione costo minima e media otteniamo

# %%
print("")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("")
print('DATI ')
print("NUMERO CITTA\' = ", 34 )
print('DIMENSIONE POPOLAZIONE =', 900)
print("NUMERO GENERAZIONI = ", 300)
print("")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("")
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# DATI
# NUMERO CITTA' =  34
# DIMENSIONE POPOLAZIONE = 900
# NUMERO GENERAZIONI =  300
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
plt.figure(figsize = (20,10), facecolor = "ALICEBLUE")
x,y = np.loadtxt("EX_9.1_CIRCONFERENZA/LBestPath.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x,y,marker=".",color="lightblue", label = "LBest")
x,y = np.loadtxt("EX_9.1_CIRCONFERENZA/L-medie.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x,y,marker=".", color="Maroon", label = "Lmedie")
plt.xlabel('$Generazione$',fontsize=12)
plt.ylabel('$L(x)$',fontsize=12)
plt.grid(True)
plt.show("circ.jpeg")

# %%
x,y = np.loadtxt("EX_9.1_CIRCONFERENZA/LBestPath.dat", usecols=(0,1), delimiter=' ', unpack='true')
print("")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("")

print('L(x) = ')
print(y[-1])
print("")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("")
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# L(x) =
# 6.28526
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
myColors = ["cornflowerblue","skyblue","aqua","DeepSkyBlue","DarkSlateBlue", "Cyan", "DarkCyan", "Azure", "Blue", "DarkBlue"]

# %%
plt.figure(figsize = (30,10), facecolor = "ALICEBLUE")

for i in range(0,8):
    plt.subplot(2,4,i+1)
    x,y = np.loadtxt("EX_9.1_CIRCONFERENZA/Configurazioni/configurazione"+str(i*10)+".dat", usecols=(0,1), unpack='true')
    plt.plot(x[1:],y[1:],label='Generazioni='+str(i*10),marker=".",color=myColors[i-1])
    plt.plot(x[0],y[0],label='Generazioni='+str(i),marker="*",ms = 10, color="r")
    
plt.show()

# %% [markdown]
# Continuando lo sviluppo...

# %%
N = [100,110,120,150,190,220,230,250,290,300, 400, 490]
myColors = ["SpringGreen","ForestGreen", "Green", "Olive", "OliveDrab", "Lime", "PaleGreen", "DarkOliveGreen",  "LightGreen", "DarkGreen", "MediumSEaGreen",
            "LimeGreen"]
conta = 1
plt.figure(figsize = (30,10), facecolor = "ALICEBLUE")
for i in N:
    plt.subplot(2,6,conta)
    x,y = np.loadtxt("EX_9.1_CIRCONFERENZA/Configurazioni/configurazione"+str(i)+".dat", usecols=(0,1), unpack='true')
    plt.plot(x[1:],y[1:],label='Generazioni='+str(i),marker=".",color=myColors[conta-1])
    plt.plot(x[0],y[0],label='Generazioni='+str(i),marker="*",ms = 10, color="r")
    conta=conta+1
plt.show()

# %% [markdown]
# Come atteso, l'ottimo risulta essere lungo la circonferneza:

# %%
plt.figure(figsize = (10,7), facecolor = "ALICEBLUE")
x,y = np.loadtxt("EX_9.1_CIRCONFERENZA/Configurazioni/configurazione300.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x[0],y[0], marker ="*", color = "Magenta", markersize = 16, label = "Start", linestyle = "")
plt.plot(x, y, marker = "o",mec = "Lime" , mfc = "lime", linestyle = "-", c = "INDIGO")
font = {'family':'serif', 'color':'forestgreen','size':'15'}
plt.ylabel('y', fontdict = font)
plt.xlabel('x', fontdict = font)
plt.grid(True)
plt.title('città', fontsize = 20, fontweight = "bold", color = "ForestGreen", family = "Serif")
plt.legend()

x = np.linspace(-1.0, 1.0, 100)
y = np.linspace(-1.0, 1.0, 100)
X, Y = np.meshgrid(x,y)
F = X**2 + Y**2 - 1
plt.contour(X,Y,F,[0], colors = "r", alpha = 0.4)

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# <h3><font color = 'LightGreen'>QUADRATO:</font></h3>

# %% [markdown]
# Andiamo a considerare la configurazione quadrata, rappresentando ancora acnitutto la distribuzione delle citta':

# %%
plt.figure(figsize = (10,7), facecolor = "ALICEBLUE")
x,y = np.loadtxt("EX_9.1_QUADRATO/Configurazioni/configurazione0.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x[0],y[0], marker ="*", color = "Magenta", markersize = 16, label = "Start", linestyle = "")
plt.plot(x, y,marker = "o",mec = "Lime" , mfc = "lime", linestyle = "None", c = "INDIGO")
plt.ylabel('y', fontsize = 15, fontweight = "bold")
plt.xlabel('x', fontsize = 15, fontweight = "bold")
plt.grid(True)
plt.title('città', fontsize = 20, fontweight = "bold")
plt.legend()

plt.axhline(y=0.5, c = "r")
plt.axhline(y=-0.5, c = "r")
plt.axvline(x=0.5, c = "r")
plt.axvline(x=-0.5, c = "r")

plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %% [markdown]
# Puo' essere ancora utile andare a visualizzare un esempio di percorso casuale; prendendo sempre quello primigenio, cioe' di input:

# %%
plt.figure(figsize = (10,7), facecolor = "ALICEBLUE")
x,y = np.loadtxt("EX_9.1_QUADRATO/Configurazioni/configurazione0.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x[0],y[0], marker ="*", color = "Magenta", markersize = 16, label = "Start", linestyle = "")
plt.plot(x, y,marker = "o",mec = "Lime" , mfc = "lime", linestyle = "-", c = "INDIGO")
plt.ylabel('y', fontsize = 15, fontweight = "bold")
plt.xlabel('x', fontsize = 15, fontweight = "bold")
plt.grid(True)
plt.title('città', fontsize = 20, fontweight = "bold")
plt.legend()

plt.axhline(y=0.5, c = "r")
plt.axhline(y=-0.5, c = "r")
plt.axvline(x=0.5, c = "r")
plt.axvline(x=-0.5, c = "r")

plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
print("")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("")
print('DATI ')
print("NUMERO CITTA\' = ", 50 )
print('DIMENSIONE POPOLAZIONE =', 500)
print("NUMERO GENERAZIONI = ", 1000)
print("")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("")
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# DATI
# NUMERO CITTA' =  50
# DIMENSIONE POPOLAZIONE = 500
# NUMERO GENERAZIONI =  1000
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# %%
plt.figure(figsize = (20,10), facecolor = "ALICEBLUE")
x,y = np.loadtxt("EX_9.1_QUADRATO/LBestPath.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x,y,marker=".",color="lightblue")
x,y = np.loadtxt("EX_9.1_QUADRATO/L-medie.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x,y,marker=".", color="Maroon")
plt.xlabel('$Generazione$',fontsize=12)
plt.ylabel('$L(x)$',fontsize=12)
plt.grid(True)
plt.savefig("circ.jpeg")

# %%
myColors = ["cornflowerblue","skyblue","aqua","DeepSkyBlue","DarkSlateBlue", "Cyan", "DarkCyan", "Azure", "Blue", "DarkBlue"]

# %%
plt.figure(figsize = (30,10), facecolor = "ALICEBLUE")

for i in range(0,8):
    plt.subplot(2,4,i+1)
    x,y = np.loadtxt("EX_9.1_QUADRATO/Configurazioni/configurazione"+str(i*10)+".dat", usecols=(0,1), unpack='true')
    plt.plot(x[0:],y[0:],label='Generazioni='+str(i*10),marker=".",ms = 10, color=myColors[i-1])
    plt.plot(x[0],y[0],label='Generazioni='+str(i),marker="*",ms = 10, color="r")
plt.show()

# %% [markdown]
# Sviluppando ancora un po' popolazione e considerando ulteriori generazione per

# %%
N = [100,110,120,160,300, 400]
for i in N:
    print("N = ", i)
# Out:
# N =  100
# N =  110
# N =  120
# N =  160
# N =  300
# N =  400

# %% [markdown]
# Otteniamo:

# %%
myColors = ["SpringGreen","ForestGreen", "Green", "Olive", "OliveDrab", "Lime", "PaleGreen", "DarkOliveGreen",  "LightGreen", "DarkGreen", "MediumSEaGreen",
            "LimeGreen"]

# %%
conta = 1
plt.figure(figsize = (30,10), facecolor = "ALICEBLUE")
for i in N:
    plt.subplot(2,3,conta)
    x,y = np.loadtxt("EX_9.1_QUADRATO/Configurazioni/configurazione"+str(i)+".dat", usecols=(0,1), unpack='true')
    plt.plot(x[0:],y[0:],label='Generazioni='+str(i),marker=".",color=myColors[conta-1])
    plt.plot(x[0],y[0],label='Generazioni='+str(i),marker="*",ms = 10, color="r")
    conta=conta+1
plt.show()

# %%
plt.figure(figsize = (10,7), facecolor = "ALICEBLUE")
x,y = np.loadtxt("EX_9.1_QUADRATO/Configurazioni/configurazione300.dat", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x[0],y[0], marker ="*", color = "Magenta", markersize = 16, label = "Start", linestyle = "")
plt.plot(x, y,marker = "o",mec = "Lime" , mfc = "lime", linestyle = "-", c = "INDIGO")
plt.ylabel('y', fontsize = 15, fontweight = "bold")
plt.xlabel('x', fontsize = 15, fontweight = "bold")
plt.grid(True)
plt.title('città', fontsize = 20, fontweight = "bold")
plt.legend()

plt.axhline(y=0.5, c = "r")
plt.axhline(y=-0.5, c = "r")
plt.axvline(x=0.5, c = "r")
plt.axvline(x=-0.5, c = "r")

plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
x,y = np.loadtxt("EX_9.1_QUADRATO/LBestPath.dat", usecols=(0,1), delimiter=' ', unpack='true')
print("")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("")

print('L(x) = ')
print(y[-1])
print("")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("")
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# L(x) =
# 6.57844
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
